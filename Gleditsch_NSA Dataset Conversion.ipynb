# %%
with open('nsa_rebel.txt', 'r', encoding="utf8", errors='ignore') as f: 
    data = f.read()
    print(data)
# Out:
# obsid	ucdpid	dyadid	side_a	acr	side_b	startdate	enddate	oldid	oldconfid	olddyadid	extraterritorial	rebpolwing	rebpolwinglegal	rebestimate	rebestlow	rebesthigh	rebstrength	centcontrol	strengthcent	mobcap	armsproc	fightcap	terrcont	terrname	effterrcont	conflicttype	transconstsupp	rebextpart	rebpresosts	presname	rebel.support	rtypesup	rsupname	gov.support	gtypesup	gsupname	govextpart	type.of.termination	victory.side	prevactive	prevact.ref	oldobsid
# NSA.3.4-1	1	462	Bolivia	BOL	Popular Revolutionary Movement	1946-06-01	1946-07-21	1010	1010.1	1010.1-1	0	acknowledged link	yes	NA	NA	NA	parity	yes	moderate	moderate	NA	moderate	no	NA	NA	coup d'etat	no	no	no		no	NA		no	NA		no	4	2	0		NSA.3.3-1
# NSA.3.4-4	1	463	Bolivia	BOL	MNR	1952-04-09	1952-04-12	1010	1010.2	1010.2-1	0	explicit link	yes	NA	NA	NA	weaker	yes	moderate	moderate	NA	moderate	no	NA	NA	coup d'etat	no	no	no		no	NA		no	NA		no	4	2	0		NSA.3.3-4
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('nsa_rebel.txt', sep='\t', engine='python', encoding="latin1")
df
# Out:
#             obsid  ucdpid  dyadid       side_a  acr  \
# 0       NSA.3.4-1       1     462      Bolivia  BOL
# 1       NSA.3.4-4       1     463      Bolivia  BOL
# 2       NSA.3.4-7       1     464      Bolivia  BOL
# 3      NSA.3.4-10       2     654       France  FRN
# 4      NSA.3.4-13       3     466        China  CHN
# ..            ...     ...     ...          ...  ...
# 573  NSA.3.4-1720     268     811     Ethiopia  ETH
# 574  NSA.3.4-1723     269     815        Sudan  SUD
# 575  NSA.3.4-1726     270     819  South Sudan  SSD
# 576  NSA.3.4-1729     271     823        Libya  LIB
# 577  NSA.3.4-1732     271     825        Libya  LIB
#
#                              side_b   startdate     enddate oldid oldconfid  \
# 0    Popular Revolutionary Movement  1946-06-01  1946-07-21  1010    1010.1
# 1                               MNR  1952-04-09  1952-04-12  1010    1010.2
# 2                               ELN  1967-03-01  1967-10-16  1010    1010.3
# ...

# %%
df.to_csv(r'C:\Users\chonlawit.sirikupt\Documents\nsa_rebel_dataset.csv', index = False)
print('saved to file path')
# Out:
# saved to file path
